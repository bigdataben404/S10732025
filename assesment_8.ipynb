# %% [markdown]
# <a href="https://colab.research.google.com/github/bigdataben404/S10732025/blob/master/assesment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("rJava")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("jiebaR")
install.packages("tmcn")
install.packages("dplyr")
install.packages("lubridate")
install.packages("stringr")
install.packages("wordcloud")
install.packages("Rwordseg,repos=http://R-Forge.R-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘jiebaRD’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘Rwordseg,repos=http://R-Forge.R-project.org’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”

# %%
library(dplyr)
library(wordcloud)
library(jiebaR)
library(lubridate)
library(stringr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: RColorBrewer
#
# Loading required package: jiebaRD
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
content<- " 起司(Cheese)是歷史非常悠久的食物，全世界加起來的起司種類高達上千種，每種都有不同的特殊香氣和口感。此外，起司的營養價值很豐富，卻因熱量高而令許多人又愛又怕，其實只要選擇天然起司並適量攝取，除了有益身體健康，甚至還能避免肥胖喔！

起司主要分成8大類：
藍紋起司(Blue Cheese)：例如拱佐諾拉乳酪(Gorgonzola)
硬質起司(Hard Cheese)：例如帕瑪森乾酪(Parmesan)
紡絲型乳酪(Pasta Filata Cheese)：例如莫札瑞拉起司(Mozzarella cheese)
加工起司(Processed Cheese)：例如美國起司(American cheese)
半硬起司(Semi-hard Cheese)：例如切達起司(Cheddar cheese)
半軟質乳酪(Semi-soft Cheese)：例如哈伐第乳酪(Havarti)
軟質新鮮乳酪(Soft fresh Cheese)：例如瑞可塔起司(Ricotta)
軟質熟成乳酪(Soft ripened Cheese)：例如布里起司(Brie)
天然的起司是用牛奶、鹽、發酵劑，以及一種被稱為凝乳酶(Rennet)的酶製成的，富含鈣質、脂肪和蛋白質，以及大量的維生素A、B12、B2、鋅(Zinc)及磷(Phosphorus)等。依據乳品、菌種與發酵時間的不同，可製造出不同種類的起司，且各具不同的營養比例。例如鈉含量較低的起司，包含瑞士起司(Swiss cheese)、瑞可塔起司和蒙特利傑克乳酪(Monterey Jack)等，而脂肪含量較低的如帕瑪森起司、磨碎的羅馬諾起司(Grated Romano)和部分脫脂的莫札瑞拉起司(Part-skim mozzarella)。一般來說，質地較軟的起司，比硬的起司含有較少的鈉。若是由完全草飼動物的乳品所製成的起司，營養成分最高，且含有omega-3脂肪酸和維生素K2。
起司對健康的好處
1. 幫助預防蛀牙
牙科綜合雜誌(General Dentistry)在2013年所發表的一項研究表示，吃起司能降低口中酸性，並保護琺瑯質(Tooth enamel)，可能是因為吃起司能促使唾液增加之故。


2. 維持骨骼健康
起司富含鈣質，任何年齡層都適合補充。不過食品與營養研究雜誌(Food & Nutrition Research)於2016年發表的文章指出，起司在兒童身上對骨骼健康的正面影響，似乎比成年人更顯著。

3. 維持心血管健康
如藍紋起司、布里起司和切達起司等高脂起司，含有少量的共軛亞麻油酸(CLA)，有研究表示，共軛亞麻油酸可幫助預防肥胖、心臟病(Heart disease)和減少體內發炎情形，若為完全草飼的動物乳源所製的起司，則含量更多。其實不只起司，其他發酵乳製品(如優格)也有類似效果。

起司含有大量飽和脂肪(Saturated fat)，最好還是攝取適量即可。根據歐洲營養學雜誌(European Journal of Nutrition)於2017年發表的分析發現，每天吃一點起司可降低患心臟病的機率，其中每天吃40克起司的人，降低心臟病風險的幅度最大。
。"
cutter <- worker(bylines=F)

# %%
cutter[content]
# Out:
#   [1] "起司"       "Cheese"     "是"         "歷史"       "非常"
#   [6] "悠久"       "的"         "食物"       "全世界"     "加"
#  [11] "起來"       "的"         "起司"       "種類"       "高達"
#  [16] "上"         "千種"       "每種"       "都"         "有"
#  [21] "不同"       "的"         "特殊"       "香氣"       "和"
#  [26] "口感"       "此外"       "起司"       "的"         "營養價值"
#  [31] "很"         "豐富"       "卻"         "因"         "熱量"
#  [36] "高而令"     "許多"       "人"         "又愛又怕"   "其實"
#  [41] "只要"       "選擇"       "天然"       "起司並"     "適量"
#  [46] "攝取"       "除了"       "有益"       "身體健康"   "甚至"
#  [51] "還能"       "避免"       "肥胖"       "喔"         "起司"
#  [56] "主要"       "分成"       "8"          "大類"       "藍紋"
#  [61] "起司"       "Blue"       "Cheese"     "例如"       "拱佐"
#  [66] "諾拉"       "乳酪"       "Gorgonzola" "硬質"       "起司"
#  [71] "Hard"       "Cheese"     "例如"       "帕瑪森"     "乾酪"
#  [76] "Parmesan"   "紡絲"       "型"         "乳酪"       "Pasta"
#  [81] "Filata"     "Cheese"     "例如"       "莫札"       "瑞拉"
# ...

# %%
new_words<-c("共軛亞麻油","凝乳酶","營養維生素")
for(i in 1:length(new_words)){new_user_word(cutter,new_words[i])}
content <- str_remove_all(content,"[0-9a-zA-Z]+?")
cutter[content]
# Out:
#   [1] "起司"     "是"       "歷史"     "非常"     "悠久"     "的"
#   [7] "食物"     "全世界"   "加"       "起來"     "的"       "起司"
#  [13] "種類"     "高達"     "上"       "千種"     "每種"     "都"
#  [19] "有"       "不同"     "的"       "特殊"     "香氣"     "和"
#  [25] "口感"     "此外"     "起司"     "的"       "營養價值" "很"
#  [31] "豐富"     "卻"       "因"       "熱量"     "高而令"   "許多"
#  [37] "人"       "又愛又怕" "其實"     "只要"     "選擇"     "天然"
#  [43] "起司並"   "適量"     "攝取"     "除了"     "有益"     "身體健康"
#  [49] "甚至"     "還能"     "避免"     "肥胖"     "喔"       "起司"
#  [55] "主要"     "分成"     "大類"     "藍紋"     "起司"     "例如"
#  [61] "拱佐"     "諾拉"     "乳酪"     "硬質"     "起司"     "例如"
#  [67] "帕瑪森"   "乾酪"     "紡絲"     "型"       "乳酪"     "例如"
#  [73] "莫札"     "瑞拉"     "起司"     "加工"     "起司"     "例如"
#  [79] "美國"     "起司"     "半硬"     "起司"     "例如"     "切達"
#  [85] "起司"     "半"       "軟質"     "乳酪"     "例如"     "哈伐"
#  [91] "第"       "乳酪"     "軟質"     "新鮮"     "乳酪"     "例如"
#  [97] "瑞可塔"   "起司"     "軟質"     "熟成"     "乳酪"     "例如"
# ...

# %%
new_words<-c("共軛亞麻油","凝乳酶","營養維生素")
writeLines(new_words,"stop_words.txt")
stop_words <- c("在","更","之","個","未","而","也","得","不過",)
writeLines(new_words,"stop_words.txt")
# Out:
# Error in c("在", "更", "之", "個", "未", "而", "也", "得", "不過", : argument 10 is empty
# Traceback:

# %%
cutter <-worker(user="new_words.txt",stop_word="stop_words.txt",bylines=FALSE)
seg_words<- cutter[content]
seg_words
# Out:
# Error in worker(user = "new_words.txt", stop_word = "stop_words.txt", : could not find function "worker"
# Traceback:

# %%
txt_freq <-freq(seg_words)
txt_freq <-arrange(txt_freq, desc(freq))
head(txt_freq)
# Out:
#   char freq
# 1 起司 36
# 2 的   31
# 3 例如  9
# 4 和    7
# 5 乳酪  7
# 6 是    4

# %%
install.packages("showtext")
library(showtext)
showtext.auto(enable = TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
par(family=("Microsoft YaHei"))

# %%
wordcloud(txt_freq$char,txt_freq$freq,min.freq=2,random.order=F,order.colors=F,colors=rainbow(nrow(txt_freq)))
# Out:
# Warning message in strwidth(words[i], cex = size[i], ...):
# “"order.colors" is not a graphical parameter”
# Warning message in strheight(words[i], cex = size[i], ...):
# “"order.colors" is not a graphical parameter”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “"order.colors" is not a graphical parameter”
# Warning message in strwidth(words[i], cex = size[i], ...):
# “"order.colors" is not a graphical parameter”
# Warning message in strheight(words[i], cex = size[i], ...):
# “"order.colors" is not a graphical parameter”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “"order.colors" is not a graphical parameter”
# Warning message in strwidth(words[i], cex = size[i], ...):
# “"order.colors" is not a graphical parameter”
# Warning message in strheight(words[i], cex = size[i], ...):
# “"order.colors" is not a graphical parameter”
# ...
